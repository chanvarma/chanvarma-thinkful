# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preparing-the-dataset" data-toc-modified-id="Preparing-the-dataset-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preparing the dataset</a></span><ul class="toc-item"><li><span><a href="#Subsetting-only-residential-data" data-toc-modified-id="Subsetting-only-residential-data-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Subsetting only residential data</a></span></li><li><span><a href="#Dropping-NaNs" data-toc-modified-id="Dropping-NaNs-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Dropping NaNs</a></span></li><li><span><a href="#Modifying-variables" data-toc-modified-id="Modifying-variables-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Modifying variables</a></span></li></ul></li><li><span><a href="#Cleaning-and-Initial-EDA" data-toc-modified-id="Cleaning-and-Initial-EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Cleaning and Initial EDA</a></span><ul class="toc-item"><li><span><a href="#Dealing-with-outliers" data-toc-modified-id="Dealing-with-outliers-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Dealing with outliers</a></span></li><li><span><a href="#Converting-categorical-variables-to-dummies" data-toc-modified-id="Converting-categorical-variables-to-dummies-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Converting categorical variables to dummies</a></span></li></ul></li><li><span><a href="#EDA-and-feature-engineering" data-toc-modified-id="EDA-and-feature-engineering-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>EDA and feature engineering</a></span></li><li><span><a href="#Building-an-initial-model" data-toc-modified-id="Building-an-initial-model-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Building an initial model</a></span></li><li><span><a href="#Revising-the-model" data-toc-modified-id="Revising-the-model-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Revising the model</a></span><ul class="toc-item"><li><span><a href="#Removing-variables-with-p-values-&gt;-0.05" data-toc-modified-id="Removing-variables-with-p-values->-0.05-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Removing variables with p-values &gt; 0.05</a></span></li><li><span><a href="#Addressing-multicollinearity" data-toc-modified-id="Addressing-multicollinearity-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Addressing multicollinearity</a></span></li><li><span><a href="#Removing-high-collinearity-categorical-features" data-toc-modified-id="Removing-high-collinearity-categorical-features-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Removing high-collinearity categorical features</a></span></li></ul></li><li><span><a href="#Exploring-interactions" data-toc-modified-id="Exploring-interactions-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Exploring interactions</a></span></li><li><span><a href="#Adding-Lasso,-Ridge-and-ElasticNet-models" data-toc-modified-id="Adding-Lasso,-Ridge-and-ElasticNet-models-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Adding Lasso, Ridge and ElasticNet models</a></span></li><li><span><a href="#Comparing-all-linear-regression-models" data-toc-modified-id="Comparing-all-linear-regression-models-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Comparing all linear regression models</a></span></li></ul></div>

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#pd.set_option("display.max_rows", 100)
#pd.set_option("display.max_columns", 100)

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'houseprices'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))
raw = pd.read_sql_query('select * from houseprices',con=engine)

# no need for an open connection, as we're only doing a single query
engine.dispose()

# %%
raw.head()
# Out:
#    id  mssubclass mszoning  lotfrontage  lotarea street alley lotshape  \
# 0   1          60       RL         65.0     8450   Pave  None      Reg
# 1   2          20       RL         80.0     9600   Pave  None      Reg
# 2   3          60       RL         68.0    11250   Pave  None      IR1
# 3   4          70       RL         60.0     9550   Pave  None      IR1
# 4   5          60       RL         84.0    14260   Pave  None      IR1
#
#   landcontour utilities  ... poolarea poolqc fence miscfeature miscval mosold  \
# 0         Lvl    AllPub  ...        0   None  None        None       0      2
# 1         Lvl    AllPub  ...        0   None  None        None       0      5
# 2         Lvl    AllPub  ...        0   None  None        None       0      9
# 3         Lvl    AllPub  ...        0   None  None        None       0      2
# 4         Lvl    AllPub  ...        0   None  None        None       0     12
#
#   yrsold  saletype  salecondition  saleprice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
#safe = raw.copy()

# %% [markdown]
# ## Preparing the dataset

# %%
data = raw.copy()
data.shape
# Out:
# (1460, 81)

# %% [markdown]
# ### Subsetting only residential data
#
# We're only interested in the data that relates to residential zoning, completely finished dwellings, and involved a 'normal' sale.

# %%
data = data.loc[data['salecondition'] == 'Normal'] #normal sales
data = data.loc[data['mszoning'].isin(['FV', 'RH', 'RL', 'RP', 'RM'])] #residential zoning
data = data.loc[data['mssubclass'] != 45] #excludes unfinished housing
data = data.loc[data['housestyle'].isin(['1Story', '1.5Fin', '2Story', '2.5Fin', 'SFoyer', 'SLvl'])] 
        #exlcuded unfinished stories

data.shape
# Out:
# (1170, 81)

# %% [markdown]
# ### Dropping NaNs

# %%
cols_to_be_dropped, rows_to_be_dropped = [], []

for v in data.columns:
    if data[v].isna().sum()/len(data) > 0.1:
        print(v, data[v].isna().sum()/len(data), "**")
        cols_to_be_dropped.append(v)
    elif data[v].isna().sum()/len(data) > 0:
        rows_to_be_dropped.append(v)
        print(v, data[v].isna().sum()/len(data))
# Out:
# lotfrontage 0.20085470085470086 **
# alley 0.9435897435897436 **
# masvnrtype 0.003418803418803419
# masvnrarea 0.003418803418803419
# bsmtqual 0.02735042735042735
# bsmtcond 0.02735042735042735
# bsmtexposure 0.028205128205128206
# bsmtfintype1 0.02735042735042735
# bsmtfintype2 0.028205128205128206
# electrical 0.0008547008547008547
# fireplacequ 0.4683760683760684 **
# garagetype 0.04871794871794872
# garageyrblt 0.04871794871794872
# garagefinish 0.04871794871794872
# garagequal 0.04871794871794872
# garagecond 0.04871794871794872
# poolqc 0.9974358974358974 **
# fence 0.8008547008547009 **
# miscfeature 0.9581196581196582 **

# %%
data.drop(columns = cols_to_be_dropped, inplace=True)
data.dropna(axis=0, inplace=True)
data.shape
# Out:
# (1080, 75)

# %% [markdown]
# ### Modifying variables

# %% [markdown]
# We make initial changes:
# * (BsmtFullBath, BsmtHalfBath) and (FullBath, HalfBath) will be combined to BsmtBaths and Baths respectively, which are then changed into categorical variables
# * YearBuilt, YearRemodAdd, GarageYrBlt will be used to create new variables that measure years since today (2019)
# * Fireplaces and garagecars will be made a categorical variable

# %%
data['bsmtbath'] = data['bsmtfullbath'] + data['bsmthalfbath']/2
data['bath'] = data['fullbath'] + data['halfbath']/2

data['time_since_house_built'] = 2019 - data['yearbuilt']
data['time_since_house_remod'] = 2019 - data['yearremodadd']
data['time_since_gar_built'] = 2019 - data['garageyrblt']

data['bsmtbath'] = data['bsmtbath'].astype('str')
data['bath'] = data['bsmtbath'].astype('str')
data['fireplaces'] = data['fireplaces'].astype('str')
data['garagecars'] = data['garagecars'].astype('str')

cols_to_be_removed = ['bsmtfullbath', 'bsmthalfbath', 'yearbuilt',
                    'fullbath', 'halfbath', 'yearremodadd', 'garageyrblt']
cols_to_be_added = ['bsmtbath', 'bath', 'time_since_house_built', 'time_since_house_remod', 'time_since_gar_built']

data.drop(columns=cols_to_be_removed, inplace = True)

# %%
x_vars = list(data.columns)
x_vars.remove('saleprice')

x_numerics, x_categorical = [], []

for v in x_vars:
    if (data[v].dtype.name == 'int64' or data[v].dtype.name == 'float64') and v != 'id':
        x_numerics.append(v)
    elif v!= 'id':
        x_categorical.append(v)

# %% [markdown]
# ## Cleaning and Initial EDA

# %% [markdown]
# ### Dealing with outliers
#
# We start by plotting histograms of the different continuous variables.

# %%
plt.figure(figsize=(15, 20))

for index, v in enumerate(x_numerics):
    plt.subplot(10, 5, index + 1)
    plt.hist(data[v])
    plt.title("({}): {}".format(index, v))

plt.tight_layout()
plt.show()

# %% [markdown]
# We see that `lotfrontage`, `lotarea`, `masvrnarea`, `bstmtfins1`, `bsmtfinsf2`, `totalbsmtsf`, `lowqualfinsf`, `screenporch`, `poolarea`, `miscval` and `screenporch` are heavily left-skewed. We look at the box plots for more information.
#
# My hypothesis is that houses in the 'Residential Low Density' zoning category (aka, estates and spread-out houses) are contributing to the outliers.

# %%
outlier_cols = ['lotarea', 'masvnrarea', 'bsmtfinsf1', 'bsmtfinsf2', 'totalbsmtsf', 'lowqualfinsf', 
                'firstflrsf', 'enclosedporch', 'threessnporch', 'screenporch', 'poolarea']

plt.figure(figsize=(12, 30))

for index, c in enumerate(outlier_cols):
    plt.subplot(10, 3, index + 1)
    sns.boxplot(data = data, x = 'mszoning', y = c, order = ['RH', 'RM', 'FV', 'RL'], whis=3)
    plt.title("({}): {}".format(index, c))

plt.tight_layout()

# %% [markdown]
# As suspected, our hypothesis is somewhat true. Houses built in the Low Density zones have (understandably) extremely large lotareas. Unfortunately there isn't a way to tell if these outlying values are accurate. As such, we must remove outliers outside the [2, 98] percentile maintain data validity and still accommodate for high-value homes.

# %%
from scipy.stats.mstats import winsorize

data2 = data.copy()

plt.figure(figsize=(12, 30))
for index, c in enumerate(outlier_cols):
    
    for zone in data['mszoning'].unique():
        data2[c].loc[data['mszoning'] == zone] = winsorize(data[c].loc[data['mszoning'] == zone], (.02, .02))
    
    plt.subplot(10, 3, index + 1)
    sns.boxplot(data = data2, x = 'mszoning', y = c, order = ['RH', 'RM', 'FV', 'RL'], whis=3)
    plt.title("({}): {}".format(index, c))

plt.tight_layout()

# %%
data2['lowqualfinsf'].mean(), data2['poolarea'].mean(), data2['threessnporch'].mean()
# Out:
# (2.0703703703703704, 0.0, 0.0)

# %%
data['lowqualfinsf'].mean(), data['poolarea'].mean(), data['threessnporch'].mean()
# Out:
# (4.7935185185185185, 1.613888888888889, 3.475925925925926)

# %% [markdown]
# These are workable results. It appears that poolarea and threessonporch have near 0 values. We drop them.

# %%
data2.drop(columns=['poolarea', 'threessnporch'], inplace=True)
x_numerics.remove('poolarea')
x_numerics.remove('threessnporch')

# %% [markdown]
# ### Converting categorical variables to dummies

# %%
cat = pd.DataFrame()

x_categorical_dummies = []

for c in x_categorical:
    temp = pd.get_dummies(data2[c], drop_first=True, prefix=c)
    x_categorical_dummies += list(temp.columns)
    
    cat = pd.concat([cat, temp], axis=1)

data2 = pd.concat([data2, cat], axis=1)
data2.drop(columns = x_categorical, inplace = True)
data2.shape
# Out:
# (1080, 211)

# %% [markdown]
# ## EDA and feature engineering

# %% [markdown]
# Since it is going to extremely time-consuming to look at 211 columns, we start by looking at the correlations of the numeric variables with target variable. We start with the numerical variables:

# %%
from numpy import tril

cols = x_numerics + ['saleprice']

matrix = np.tril(data2[cols].corr())

plt.figure(figsize=(1, 16))

ax = sns.heatmap(data2[cols].corr()['saleprice'].to_frame(), annot=True, fmt='.3f', cmap='PiYG',
                 center=0, vmax=1, vmin=-1)

# %% [markdown]
# We start by looking at the distributions of the variables with a absolute correlation >= 0.50. As such, these have a relatively high correlation with the target variable, and might be possible explanatory features.

# %%
poss_features = []

corr = data2.corr()

for v in x_numerics:
    if abs(data2.corr()['saleprice'][v]) >= 0.5:
        poss_features.append(v)
        print("{}, corr: {}".format(v, data2.corr()['saleprice'][v]))
        
poss_features
# Out:
# overallqual, corr: 0.7814556315893234
# totalbsmtsf, corr: 0.6019711038487187
# firstflrsf, corr: 0.596466844807092
# grlivarea, corr: 0.7484607034255527
# totrmsabvgrd, corr: 0.5388600507212824
# garagearea, corr: 0.5957705661297502
# ['overallqual',
#  'totalbsmtsf',
#  'firstflrsf',
#  'grlivarea',
#  'totrmsabvgrd',
#  'garagearea']

# %%
plt.figure(figsize=(15, 10))

for index, v in enumerate(poss_features):
    plt.subplot(4, 5, index + 1)
    plt.scatter(data2[v], data2['saleprice'])
    plt.title(v)

plt.tight_layout()
plt.show()

# %% [markdown]
# We have our initial set of 15 explanatory numerical variables. We do the same with categorical variables.

# %%
for v in x_categorical_dummies:
    if abs(data2.corr()['saleprice'][v]) >= 0.5:
        poss_features.append(v)
        print("{}, corr: {} **".format(v, data2.corr()['saleprice'][v]))
# Out:
# exterqual_TA, corr: -0.5744876241281602 **
# kitchenqual_TA, corr: -0.5182441426562464 **
# garagecars_3, corr: 0.5759168004531827 **

# %%
initial_feats = poss_features.copy()

len(poss_features), poss_features
# Out:
# (9,
#  ['overallqual',
#   'totalbsmtsf',
#   'firstflrsf',
#   'grlivarea',
#   'totrmsabvgrd',
#   'garagearea',
#   'exterqual_TA',
#   'kitchenqual_TA',
#   'garagecars_3'])

# %%
poss_features = initial_feats.copy()

# %% [markdown]
# We have our initial list of 20 explanatory variables.

# %% [markdown]
# ## Building an initial model

# %%
from statsmodels.tools.eval_measures import mse, rmse
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNetCV

all_models = dict()


def model_checker(data, features, return_model=False, reg_type = "OLS"):
    """
        reg_type: 'OLS', 'lassoCV', 'ridgeCV' or 'elasticnetCV'

    """
    
    X = data[features]
    Y = data['saleprice']

    X = sm.add_constant(X)

    X_train, X_test, Y_train, Y_test = train_test_split(
        X, Y, random_state=13, test_size=0.33)

    print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
    
    alphas = [10**e for e in range(1, 10)]

    if reg_type.lower() == 'lassocv':
        
        modelv1 = LassoCV(alphas=alphas)
        modelv1.fit(X_train, Y_train)
    elif reg_type.lower() == 'ridgecv':
        modelv1 = RidgeCV(alphas=alphas)
        modelv1.fit(X_train, Y_train)     
    elif reg_type.lower() == 'elasticnetcv':
        modelv1 = ElasticNetCV(alphas=alphas, l1_ratio=0.5)
        modelv1.fit(X_train, Y_train)
    else:
        modelv1 = sm.OLS(Y_train, X_train).fit()

    Y_pred = modelv1.predict(X_test)

    plt.scatter(Y_pred, Y_test)
    plt.plot(Y_test, Y_test, color="red")
    plt.xlabel('true values')
    plt.ylabel('predicted values')
    plt.show()

    print("Mean absolute error of the prediction is: {}".format(
        mean_absolute_error(Y_test, Y_pred)))
    print("Mean squared error of the prediction is: {}".format(mse(Y_test, Y_pred)))
    print("Root mean squared error of the prediction is: {}".format(
        rmse(Y_test, Y_pred)))
    print("Mean absolute percentage error of the prediction is: {}".format(
        np.mean(np.abs((Y_test - Y_pred) / Y_test)) * 100))
    print("")

    all_models[len(all_models) + 1] = {'features': features.copy(),
                                       'regression_type': reg_type.lower(), 
                                       'n_features': len(features),
                                       'AIC': 0, 'BIC': 0,
                                       'MAE': mean_absolute_error(Y_test, Y_pred),
                                       'MSE': mse(Y_test, Y_pred),
                                       'RMSE': rmse(Y_test, Y_pred),
                                       'MAPE': np.mean(np.abs((Y_test - Y_pred) / Y_test)) * 100,
                                       'adj_r_squared_train': 0, 'adj_r_squared_test': 0, 'alpha_param': 0
                                       }

    if reg_type.lower() == 'ols':
        all_models[len(all_models)]['adj_r_squared_train'] = modelv1.rsquared_adj
        all_models[len(all_models)]['AIC'] = modelv1.aic
        all_models[len(all_models)]['BIC'] = modelv1.bic
        all_models[len(all_models)]['alpha_param'] = None
        print(modelv1.summary())
    else:
        all_models[len(all_models)]['adj_r_squared_train'] = modelv1.score(X_train, Y_train)
        all_models[len(all_models)]['adj_r_squared_test'] = modelv1.score(X_test, Y_test)
        all_models[len(all_models)]['alpha_param'] = modelv1.alpha_
        
        print(all_models[len(all_models)])
        
    if return_model:
        return modelv1
    else:
        return

# %%
model_checker(data2, poss_features)
# Out:
# (723, 10) (357, 10) (723,) (357,)
# Mean absolute error of the prediction is: 20870.250067604095
# Mean squared error of the prediction is: 796241256.3232539
# Root mean squared error of the prediction is: 28217.74718724466
# Mean absolute percentage error of the prediction is: 12.193929154217638
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.822
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     364.7
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          5.72e-260
# Time:                        23:53:17   Log-Likelihood:                -8456.5
# No. Observations:                 723   AIC:                         1.693e+04
# Df Residuals:                     713   BIC:                         1.698e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const          -4.906e+04   9872.751     -4.969      0.000   -6.84e+04   -2.97e+04
# overallqual     1.715e+04   1338.430     12.816      0.000    1.45e+04    1.98e+04
# totalbsmtsf       48.7104      7.062      6.897      0.000      34.845      62.576
# firstflrsf        -6.1135      7.144     -0.856      0.392     -20.139       7.912
# grlivarea         69.0768      4.714     14.652      0.000      59.821      78.332
# totrmsabvgrd   -4807.7193   1308.568     -3.674      0.000   -7376.826   -2238.613
# garagearea        22.8214      8.559      2.666      0.008       6.017      39.626
# exterqual_TA   -1891.8349   3405.562     -0.556      0.579   -8577.963    4794.293
# kitchenqual_TA -1.134e+04   2967.772     -3.820      0.000   -1.72e+04   -5510.036
# garagecars_3    2.627e+04   4763.685      5.514      0.000    1.69e+04    3.56e+04
# ==============================================================================
# Omnibus:                      297.442   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4305.775
# Skew:                           1.443   Prob(JB):                         0.00
# Kurtosis:                      14.602   Cond. No.                     2.18e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Revising the model

# %% [markdown]
# ### Removing variables with p-values > 0.05

# %%
poss_features.remove('firstflrsf')
poss_features.remove('exterqual_TA')

model_checker(data2, poss_features)
# Out:
# (723, 8) (357, 8) (723,) (357,)
# Mean absolute error of the prediction is: 20921.2628234669
# Mean squared error of the prediction is: 800269017.4430932
# Root mean squared error of the prediction is: 28289.02644919215
# Mean absolute percentage error of the prediction is: 12.221514739449118
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.821
# Model:                            OLS   Adj. R-squared:                  0.819
# Method:                 Least Squares   F-statistic:                     469.2
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          2.22e-262
# Time:                        23:53:17   Log-Likelihood:                -8457.2
# No. Observations:                 723   AIC:                         1.693e+04
# Df Residuals:                     715   BIC:                         1.697e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           -5.17e+04   8923.837     -5.794      0.000   -6.92e+04   -3.42e+04
# overallqual     1.752e+04   1247.197     14.051      0.000    1.51e+04       2e+04
# totalbsmtsf       43.6772      3.760     11.617      0.000      36.296      51.059
# grlivarea         68.3288      4.558     14.992      0.000      59.381      77.277
# totrmsabvgrd   -4940.3214   1298.378     -3.805      0.000   -7489.411   -2391.231
# garagearea        22.5089      8.527      2.640      0.008       5.769      39.249
# kitchenqual_TA -1.218e+04   2641.078     -4.612      0.000   -1.74e+04   -6995.966
# garagecars_3    2.693e+04   4718.723      5.708      0.000    1.77e+04    3.62e+04
# ==============================================================================
# Omnibus:                      296.014   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4296.881
# Skew:                           1.432   Prob(JB):                         0.00
# Kurtosis:                      14.594   Cond. No.                     1.71e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.71e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ### Addressing multicollinearity

# %% [markdown]
# We start by looking at the correlation between the various feautures explore the issue:

# %%
cols = poss_features + ['saleprice']

matrix = np.tril(data2[cols].corr())

plt.figure(figsize=(13, 13))

ax = sns.heatmap(data2[cols].corr(), annot=True, fmt='.2f', cmap='PiYG',
                 center=0, vmax=1, vmin=-1, cbar = False, mask = matrix, 
                 linecolor='grey', linewidths=0.05)

# %% [markdown]
# ### Removing high-collinearity categorical features
#
# We can start out by removing the categorical variables that are dummies of the same category. We will pick the one with the higher absolute value correlation with 'saleprice'.

# %%
poss_features
# Out:
# ['overallqual',
#  'totalbsmtsf',
#  'grlivarea',
#  'totrmsabvgrd',
#  'garagearea',
#  'kitchenqual_TA',
#  'garagecars_3']

# %%
poss_features.remove('totrmsabvgrd')
poss_features.remove('garagecars_3')
poss_features.remove('overallqual')
poss_features.remove('totalbsmtsf')

# %%
cols = poss_features + ['saleprice']

matrix = np.tril(data2[cols].corr())

plt.figure(figsize=(4, 4))

ax = sns.heatmap(data2[cols].corr(), annot=True, fmt='.2f', cmap='PiYG',
                 center=0, vmax=1, vmin=-1, cbar = False, mask = matrix, 
                 linecolor='grey', linewidths=0.05)

# %%
model_checker(data2, poss_features)
# Out:
# (723, 4) (357, 4) (723,) (357,)
# Mean absolute error of the prediction is: 27921.503032450604
# Mean squared error of the prediction is: 1527672600.0817754
# Root mean squared error of the prediction is: 39085.45253776365
# Mean absolute percentage error of the prediction is: 16.294932464521782
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.692
# Model:                            OLS   Adj. R-squared:                  0.691
# Method:                 Least Squares   F-statistic:                     539.6
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          1.44e-183
# Time:                        23:53:18   Log-Likelihood:                -8653.3
# No. Observations:                 723   AIC:                         1.731e+04
# Df Residuals:                     719   BIC:                         1.733e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            2.91e+04   6515.137      4.467      0.000    1.63e+04    4.19e+04
# grlivarea         79.3863      3.334     23.812      0.000      72.841      85.932
# garagearea       101.0590      9.458     10.685      0.000      82.491     119.627
# kitchenqual_TA -3.398e+04   3109.872    -10.926      0.000   -4.01e+04   -2.79e+04
# ==============================================================================
# Omnibus:                      272.963   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3059.413
# Skew:                           1.366   Prob(JB):                         0.00
# Kurtosis:                      12.700   Cond. No.                     7.97e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.97e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
poss_features
# Out:
# ['grlivarea', 'garagearea', 'kitchenqual_TA']

# %% [markdown]
# ## Exploring interactions

# %% [markdown]
# We start with our initial list of features and look for possible interactions.

# %%
cols = initial_feats + ['saleprice']

matrix = np.tril(data2[cols].corr())

plt.figure(figsize=(8, 8))

ax = sns.heatmap(data2[cols].corr(), annot=True, fmt='.2f', cmap='PiYG',
                 center=0, vmax=1, vmin=-1, cbar = False, mask = matrix, 
                 linecolor='grey', linewidths=0.05)

# %% [markdown]
# Let us exclude `overallqual`, and look at interactions between `firstfirsf` and `grlivarea`.

# %%
data2['firstflrsf*grlivarea'] = data2['firstflrsf'] * data2['grlivarea']
poss_features = initial_feats.copy()

poss_features.append('firstflrsf*grlivarea')
poss_features.remove('overallqual')
poss_features.remove('grlivarea')
poss_features.remove('firstflrsf')

model_checker(data2, poss_features)
# Out:
# (723, 8) (357, 8) (723,) (357,)
# Mean absolute error of the prediction is: 24469.82482477091
# Mean squared error of the prediction is: 1078795201.6247487
# Root mean squared error of the prediction is: 32845.0179117739
# Mean absolute percentage error of the prediction is: 14.05737150882413
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.764
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     331.2
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          1.54e-219
# Time:                        23:53:18   Log-Likelihood:                -8557.1
# No. Observations:                 723   AIC:                         1.713e+04
# Df Residuals:                     715   BIC:                         1.717e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1.028e+05   9743.294     10.554      0.000    8.37e+04    1.22e+05
# totalbsmtsf              5.9587      5.731      1.040      0.299      -5.292      17.209
# totrmsabvgrd          2062.9993   1237.416      1.667      0.096    -366.403    4492.402
# garagearea              38.4590      9.725      3.955      0.000      19.367      57.551
# exterqual_TA         -2.618e+04   3559.305     -7.357      0.000   -3.32e+04   -1.92e+04
# kitchenqual_TA       -1.962e+04   3347.947     -5.859      0.000   -2.62e+04    -1.3e+04
# garagecars_3          3.497e+04   5367.116      6.516      0.000    2.44e+04    4.55e+04
# firstflrsf*grlivarea     0.0344      0.002     14.020      0.000       0.030       0.039
# ==============================================================================
# Omnibus:                      138.845   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1320.261
# Skew:                           0.553   Prob(JB):                    2.04e-287
# Kurtosis:                       9.527   Cond. No.                     1.69e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.69e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# We see that the p-value for `totalbsmtsf` is > 0.05, so we remove. We also remove `garagecars_3` to reduce multicollinearity.
#
# We also interact `exterqual_TA` and `kitchenqual_TA`.

# %%
data2['exterqual_TA*kitchenqual_TA'] = data2['exterqual_TA'] * data2['kitchenqual_TA']

poss_features.append('exterqual_TA*kitchenqual_TA')
poss_features.remove('exterqual_TA')
poss_features.remove('kitchenqual_TA')
poss_features.remove('totalbsmtsf')
poss_features.remove('garagecars_3')

model_checker(data2, poss_features)
# Out:
# (723, 5) (357, 5) (723,) (357,)
# Mean absolute error of the prediction is: 26633.011904261442
# Mean squared error of the prediction is: 1321927674.7380834
# Root mean squared error of the prediction is: 36358.323321326076
# Mean absolute percentage error of the prediction is: 15.45414606931411
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.725
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     474.1
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          8.43e-200
# Time:                        23:53:18   Log-Likelihood:                -8612.4
# No. Observations:                 723   AIC:                         1.723e+04
# Df Residuals:                     718   BIC:                         1.726e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        7.372e+04   7405.799      9.954      0.000    5.92e+04    8.83e+04
# totrmsabvgrd                 2170.5622   1193.328      1.819      0.069    -172.267    4513.392
# garagearea                     81.4848      9.144      8.911      0.000      63.532      99.438
# firstflrsf*grlivarea            0.0386      0.002     19.920      0.000       0.035       0.042
# exterqual_TA*kitchenqual_TA  -3.55e+04   2905.778    -12.216      0.000   -4.12e+04   -2.98e+04
# ==============================================================================
# Omnibus:                      122.694   Durbin-Watson:                   1.938
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1054.933
# Skew:                           0.472   Prob(JB):                    8.40e-230
# Kurtosis:                       8.842   Cond. No.                     1.18e+07
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# We remove `totrmsabvgrd` as p-value > 0.05.

# %%
poss_features.remove('totrmsabvgrd')

model_checker(data2, poss_features)
# Out:
# (723, 4) (357, 4) (723,) (357,)
# Mean absolute error of the prediction is: 26694.885180210502
# Mean squared error of the prediction is: 1315349716.9978065
# Root mean squared error of the prediction is: 36267.750371339636
# Mean absolute percentage error of the prediction is: 15.477647662403138
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              saleprice   R-squared:                       0.724
# Model:                            OLS   Adj. R-squared:                  0.723
# Method:                 Least Squares   F-statistic:                     629.0
# Date:                Thu, 09 Jan 2020   Prob (F-statistic):          1.61e-200
# Time:                        23:53:19   Log-Likelihood:                -8614.0
# No. Observations:                 723   AIC:                         1.724e+04
# Df Residuals:                     719   BIC:                         1.725e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================================
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                        8.353e+04   5083.426     16.431      0.000    7.35e+04    9.35e+04
# garagearea                     81.7216      9.158      8.923      0.000      63.742      99.701
# firstflrsf*grlivarea            0.0408      0.002     26.955      0.000       0.038       0.044
# exterqual_TA*kitchenqual_TA -3.537e+04   2909.614    -12.157      0.000   -4.11e+04   -2.97e+04
# ==============================================================================
# Omnibus:                      116.640   Durbin-Watson:                   1.936
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              904.441
# Skew:                           0.466   Prob(JB):                    4.01e-197
# Kurtosis:                       8.400   Cond. No.                     8.45e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.45e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Adding Lasso, Ridge and ElasticNet models

# %%
model_checker(data2, initial_feats, reg_type='ridgecv')
# Out:
# (723, 10) (357, 10) (723,) (357,)
# Mean absolute error of the prediction is: 20815.252227876263
# Mean squared error of the prediction is: 797950122.2218086
# Root mean squared error of the prediction is: 28248.0109427515
# Mean absolute percentage error of the prediction is: 12.164265678231182
#
# {'features': ['overallqual', 'totalbsmtsf', 'firstflrsf', 'grlivarea', 'totrmsabvgrd', 'garagearea', 'exterqual_TA', 'kitchenqual_TA', 'garagecars_3'], 'regression_type': 'ridgecv', 'n_features': 9, 'AIC': 0, 'BIC': 0, 'MAE': 20815.252227876263, 'MSE': 797950122.2218086, 'RMSE': 28248.0109427515, 'MAPE': 12.164265678231182, 'adj_r_squared_train': 0.8211811071905495, 'adj_r_squared_test': 0.8326290555737579, 'alpha_param': 10}

# %%
x = model_checker(data2, initial_feats, reg_type='lassoCV', return_model=True)
# Out:
# (723, 10) (357, 10) (723,) (357,)
# Mean absolute error of the prediction is: 20843.909723826797
# Mean squared error of the prediction is: 796946859.2202333
# Root mean squared error of the prediction is: 28230.247239799963
# Mean absolute percentage error of the prediction is: 12.179570018501677
#
# {'features': ['overallqual', 'totalbsmtsf', 'firstflrsf', 'grlivarea', 'totrmsabvgrd', 'garagearea', 'exterqual_TA', 'kitchenqual_TA', 'garagecars_3'], 'regression_type': 'lassocv', 'n_features': 9, 'AIC': 0, 'BIC': 0, 'MAE': 20843.909723826797, 'MSE': 796946859.2202333, 'RMSE': 28230.247239799963, 'MAPE': 12.179570018501677, 'adj_r_squared_train': 0.8214798503568015, 'adj_r_squared_test': 0.8328394911278173, 'alpha_param': 100}

# %% [markdown]
# ## Comparing all linear regression models

# %%
lowest_AIC = {'metric': 'AIC', 'model': '', 'regression_type': '', 'value': 10 ** 100}
lowest_BIC = {'metric': 'BIC', 'model': '', 'regression_type': '', 'value': 10 ** 100}
lowest_MAE = {'metric': 'MAE', 'model': '', 'regression_type': '', 'value': 10 ** 100}
lowest_MSE = {'metric': 'MSE', 'model': '', 'regression_type': '', 'value': 10 ** 100}
lowest_RMSE = {'metric': 'RMSE', 'model': '', 'regression_type': '', 'value': 10 ** 100}
lowest_MAPE = {'metric': 'MAPE', 'model': '', 'regression_type': '', 'value': 10 ** 100}
highest_adj_rsquared_train = {'metric': 'adj_r_squared_train', 'model': '', 'regression_type': '', 'value': -10 ** 100}
highest_adj_rsquared_test = {'metric': 'adj_r_squared_test', 'model': '', 'regression_type': '', 'value': -10 ** 100}

scores = [lowest_AIC, lowest_BIC, lowest_MAE, lowest_MAPE, lowest_MSE, lowest_RMSE, highest_adj_rsquared_train, highest_adj_rsquared_test]


def get_best_model():
    for key in all_models.keys():
        for metric_dict in scores:
            metric = metric_dict['metric']
            
            conditions = (all_models[key][metric] <= metric_dict['value']) or \
            (all_models[key][metric] >= metric_dict['value'] and metric == 'adj_r_squared_test') or \
            (all_models[key][metric] >= metric_dict['value'] and metric == 'adj_r_squared_train')
            
            if conditions and all_models[key][metric] != 0:
                metric_dict['model'] = key 
                metric_dict['value'] = all_models[key][metric]
                metric_dict['regression_type'] = all_models[key]['regression_type']
                
    for metric_dict in scores:
        if abs(metric_dict['value']) == 10 ** 100:
            metric_dict['value'] = ''

get_best_model()
scores
# Out:
# [{'metric': 'AIC',
#   'model': 2,
#   'regression_type': 'ols',
#   'value': 16930.315579883754},
#  {'metric': 'BIC',
#   'model': 2,
#   'regression_type': 'ols',
#   'value': 16966.982853661026},
#  {'metric': 'MAE',
#   'model': 7,
#   'regression_type': 'ridgecv',
#   'value': 20815.252227876263},
#  {'metric': 'MAPE',
#   'model': 7,
#   'regression_type': 'ridgecv',
#   'value': 12.164265678231182},
#  {'metric': 'MSE',
#   'model': 1,
#   'regression_type': 'ols',
#   'value': 796241256.3232539},
#  {'metric': 'RMSE',
#   'model': 1,
#   'regression_type': 'ols',
#   'value': 28217.74718724466},
#  {'metric': 'adj_r_squared_train',
#   'model': 8,
#   'regression_type': 'lassocv',
#   'value': 0.8214798503568015},
#  {'metric': 'adj_r_squared_test',
#   'model': 8,
#   'regression_type': 'lassocv',
#   'value': 0.8328394911278173}]

# %% [markdown]
# It appears that the best performing models are models7 and model8.

# %%
all_models[7]
# Out:
# {'features': ['overallqual',
#   'totalbsmtsf',
#   'firstflrsf',
#   'grlivarea',
#   'totrmsabvgrd',
#   'garagearea',
#   'exterqual_TA',
#   'kitchenqual_TA',
#   'garagecars_3'],
#  'regression_type': 'ridgecv',
#  'n_features': 9,
#  'AIC': 0,
#  'BIC': 0,
#  'MAE': 20815.252227876263,
#  'MSE': 797950122.2218086,
#  'RMSE': 28248.0109427515,
#  'MAPE': 12.164265678231182,
#  'adj_r_squared_train': 0.8211811071905495,
#  'adj_r_squared_test': 0.8326290555737579,
#  'alpha_param': 10}

# %%
all_models[8]
# Out:
# {'features': ['overallqual',
#   'totalbsmtsf',
#   'firstflrsf',
#   'grlivarea',
#   'totrmsabvgrd',
#   'garagearea',
#   'exterqual_TA',
#   'kitchenqual_TA',
#   'garagecars_3'],
#  'regression_type': 'lassocv',
#  'n_features': 9,
#  'AIC': 0,
#  'BIC': 0,
#  'MAE': 20843.909723826797,
#  'MSE': 796946859.2202333,
#  'RMSE': 28230.247239799963,
#  'MAPE': 12.179570018501677,
#  'adj_r_squared_train': 0.8214798503568015,
#  'adj_r_squared_test': 0.8328394911278173,
#  'alpha_param': 100}
