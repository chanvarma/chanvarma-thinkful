# %% [markdown]
# # 20.8 Challenge

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preparing-the-data" data-toc-modified-id="Preparing-the-data-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Preparing the data</a></span><ul class="toc-item"><li><span><a href="#Dealing-with-missing-values" data-toc-modified-id="Dealing-with-missing-values-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Dealing with missing values</a></span></li></ul></li></ul></div>

# %% [markdown]
# In this challenge, you'll work with the [Life Expectancy dataset](https://www.kaggle.com/kumarajarshi/life-expectancy-who/home) from Kaggle. The data is collected from the websites of the World Health Organisation (WHO) and World Bank (WB). The dataset contains annual variables for many of the countries in the world which are divided into several broad categories: immunization related factors, mortality factors, economical factors, and social factors.
#
# You should access the data from the Thinkful database. Here's the credentials you can use to connect to the database:
#
# `postgres_user = 'dsbc_student'
# postgres_pw = '7\*.8G9QH21'
# postgres_host = '142.93.121.174'
# postgres_port = '5432'
# postgres_db = 'lifeexpectancy'
# table_name = 'lifeexpectancy'`
#
# To complete this challenge, submit a Jupyter notebook containing your solutions to the following tasks. Moreover, you can also submit a kernel to the Kaggle containing your solutions.
#
# * Your goal in this challenge is to find the factors that affect the life expectancy. Specifically, you need to find out which factors increase the expected life in the countries and which factors decrease it.
#
# * First, load the dataset.
#
# * Detect the problems with the data such as missing values and outliers. Are there any nonsense values that seem to be stemmed from the data collection? For the missing values, discuss which technique would be the most suitable one in filling out these values. Regarding the outliers, discuss their potential effects on your analysis and select an appropriate method to deal with them.
#
# * Explore the data using univariate and multivariate exploration techniques. You should pay special attention to your target variable. In this regard, your focus should be on finding the relevant variables that may affect life expectancy.
#
# * In the feature engineering step, you need to select a suite of variables that you think would be ideal in the modeling phase. More concretely, you may discard some variables that are very correlated with the other ones or the variables that you think irrelevant with the life expectancy.
#
# * Summarize your findings. One of the most important skills of a data scientist is to convey ideas and findings to nontechnical people using understandable language. In this regard, one of the most effective ways to communicate your ideas is to do it using effective visualization.

# %% [markdown]
# ## Preparing the data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
from scipy.stats.mstats import winsorize
from sqlalchemy import create_engine
import warnings

warnings.filterwarnings('ignore')
sns.set(style="whitegrid")

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'lifeexpectancy'

# %%
engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

data = pd.read_sql_query('select * from lifeexpectancy',con=engine)
engine.dispose()

# %%
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
# 3   67.0               8.52         67.0        0.1  669.959000   3696958.0
# 4   68.0               7.87         68.0        0.1   63.537231   2978599.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
# 3                   17.9                 18.0
# 4                   18.2                 18.2
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
# 3                            0.463        9.8
# 4                            0.454        9.5
#
# [5 rows x 22 columns]

# %%
data.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# dtype: object

# %%
data.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# min       0.010000                0.000000     1.000000       0.000000
# 25%       0.877500                4.685343    77.000000       0.000000
# 50%       3.755000               64.912906    92.000000      17.000000
# 75%       7.702500              441.534144    97.000000     360.250000
# max      17.870000            19479.911610    99.000000  212183.000000
#
#               BMI   under-five deaths         Polio  Total expenditure  \
# count  2904.000000         2938.000000  2919.000000         2712.00000
# mean     38.321247           42.035739    82.550188            5.93819
# std      20.044034          160.445548    23.428046            2.49832
# min       1.000000            0.000000     3.000000            0.37000
# 25%      19.300000            0.000000    78.000000            4.26000
# 50%      43.500000            4.000000    93.000000            5.75500
# 75%      56.200000           28.000000    97.000000            7.49250
# max      87.300000         2500.000000    99.000000           17.60000
#
#        Diphtheria      HIV/AIDS            GDP    Population  \
# count  2919.000000  2938.000000    2490.000000  2.286000e+03
# mean     82.324084     1.742103    7483.158469  1.275338e+07
# std      23.716912     5.077785   14270.169342  6.101210e+07
# min       2.000000     0.100000       1.681350  3.400000e+01
# 25%      78.000000     0.100000     463.935626  1.957932e+05
# 50%      93.000000     0.100000    1766.947595  1.386542e+06
# 75%      97.000000     0.800000    5910.806335  7.420359e+06
# max      99.000000    50.600000  119172.741800  1.293859e+09
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling
# count                      2771.000000  2775.000000
# mean                          0.627551    11.992793
# std                           0.210904     3.358920
# min                           0.000000     0.000000
# 25%                           0.493000    10.100000
# 50%                           0.677000    12.300000
# 75%                           0.779000    14.300000
# max                           0.948000    20.700000

# %% [markdown]
# ### Dealing with missing values

# %%
data2 = data.copy()
print(id(data), id(data2))
# Out:
# 112075916432 112226877072

# %%
data.isna().sum()/data.isna().count()
# Out:
# Country                            0.000000
# Year                               0.000000
# Status                             0.000000
# Life expectancy                    0.003404
# Adult Mortality                    0.003404
# infant deaths                      0.000000
# Alcohol                            0.066031
# percentage expenditure             0.000000
# Hepatitis B                        0.188223
# Measles                            0.000000
#  BMI                               0.011572
# under-five deaths                  0.000000
# Polio                              0.006467
# Total expenditure                  0.076923
# Diphtheria                         0.006467
#  HIV/AIDS                          0.000000
# GDP                                0.152485
# Population                         0.221920
#  thinness  1-19 years              0.011572
#  thinness 5-9 years                0.011572
# Income composition of resources    0.056841
# Schooling                          0.055480
# dtype: float64

# %% [markdown]
# Some variables contain missing values, so we start by interpolating the data for a given country.

# %%
for country in data2['Country'].unique():
    data2.loc[data2['Country'] == country] = data2.loc[data2['Country'] == country].interpolate()
    
data.isna().sum()/data.isna().count() - data2.isna().sum()/data2.isna().count()
# Out:
# Country                            0.000000
# Year                               0.000000
# Status                             0.000000
# Life expectancy                    0.000000
# Adult Mortality                    0.000000
# infant deaths                      0.000000
# Alcohol                            0.000681
# percentage expenditure             0.000000
# Hepatitis B                        0.139210
# Measles                            0.000000
#  BMI                               0.000000
# under-five deaths                  0.000000
# Polio                              0.006467
# Total expenditure                  0.005446
# Diphtheria                         0.006467
#  HIV/AIDS                          0.000000
# GDP                                0.008850
# Population                         0.000000
#  thinness  1-19 years              0.000000
#  thinness 5-9 years                0.000000
# Income composition of resources    0.000000
# Schooling                          0.000000
# dtype: float64

# %% [markdown]
# There still remain some missing values, so we dive deeper into the types of missing values.

# %%
data2.shape
# Out:
# (2938, 22)

# %%
data2.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            192
# percentage expenditure               0
# Hepatitis B                        144
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                                0
# Total expenditure                  210
# Diphtheria                           0
#  HIV/AIDS                            0
# GDP                                422
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
data2['Year'].loc[data2.isna().any(axis = 1)].value_counts()
# Out:
# 2015    181
# 2013     62
# 2014     52
# 2012     52
# 2011     51
# 2010     51
# 2009     51
# 2008     51
# 2007     50
# 2006     50
# 2005     50
# 2004     50
# 2003     50
# 2002     50
# 2001     50
# 2000     50
# Name: Year, dtype: int64

# %% [markdown]
# Since the data spans 2000-2015, it is quite likely that 2015 estimates are incomplete. As a result, we will drop the rows where `Year` = 2015.

# %%
data2 = data2.loc[data2['Year'] != 2015]
data2.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                             16
# percentage expenditure               0
# Hepatitis B                        135
# Measles                              0
#  BMI                                32
# under-five deaths                    0
# Polio                                0
# Total expenditure                   30
# Diphtheria                           0
#  HIV/AIDS                            0
# GDP                                393
# Population                         611
#  thinness  1-19 years               32
#  thinness 5-9 years                 32
# Income composition of resources    157
# Schooling                          153
# dtype: int64

# %% [markdown]
# We now explore countries...

# %%
data2['Country'].loc[data2.isna().any(axis = 1)].value_counts()[:15]
# Out:
# Iceland                                      15
# Oman                                         15
# Libya                                        15
# Czechia                                      15
# Côte d'Ivoire                                15
# Qatar                                        15
# The former Yugoslav republic of Macedonia    15
# Antigua and Barbuda                          15
# Bahrain                                      15
# Brunei Darussalam                            15
# Gambia                                       15
# Cuba                                         15
# Hungary                                      15
# United States of America                     15
# Sudan                                        15
# Name: Country, dtype: int64

# %%
data2.loc[data2.isna().any(axis = 1)].groupby(by = 'Country').count()
# Out:
#                                     Year  Status  Life expectancy   \
# Country
# Antigua and Barbuda                   15      15                15
# Bahamas                               15      15                15
# Bahrain                               15      15                15
# Barbados                              15      15                15
# Bolivia (Plurinational State of)      15      15                15
# ...                                  ...     ...               ...
# United Republic of Tanzania           15      15                15
# United States of America              15      15                15
# Venezuela (Bolivarian Republic of)    15      15                15
# Viet Nam                              15      15                15
# Yemen                                 15      15                15
#
#                                     Adult Mortality  infant deaths  Alcohol  \
# Country
# Antigua and Barbuda                              15             15       15
# Bahamas                                          15             15       15
# Bahrain                                          15             15       15
# Barbados                                         15             15       15
# Bolivia (Plurinational State of)                 15             15       15
# ...                                             ...            ...      ...
# United Republic of Tanzania                      15             15       15
# United States of America                         15             15       15
# Venezuela (Bolivarian Republic of)               15             15       15
# Viet Nam                                         15             15       15
# Yemen                                            15             15       15
#
#                                     percentage expenditure  Hepatitis B  \
# Country
# Antigua and Barbuda                                     15           15
# Bahamas                                                 15           15
# Bahrain                                                 15           15
# Barbados                                                15           15
# Bolivia (Plurinational State of)                        15           15
# ...                                                    ...          ...
# United Republic of Tanzania                             15           15
# United States of America                                15           15
# Venezuela (Bolivarian Republic of)                      15           15
# Viet Nam                                                15           15
# Yemen                                                   15           15
#
#                                     Measles    BMI   ...  Polio  \
# Country                                              ...
# Antigua and Barbuda                       15     15  ...     15
# Bahamas                                   15     15  ...     15
# Bahrain                                   15     15  ...     15
# Barbados                                  15     15  ...     15
# Bolivia (Plurinational State of)          15     15  ...     15
# ...                                      ...    ...  ...    ...
# United Republic of Tanzania               15     15  ...     15
# United States of America                  15     15  ...     15
# Venezuela (Bolivarian Republic of)        15     15  ...     15
# Viet Nam                                  15     15  ...     15
# Yemen                                     15     15  ...     15
#
#                                     Total expenditure  Diphtheria    HIV/AIDS  \
# Country
# Antigua and Barbuda                                15           15         15
# Bahamas                                            15           15         15
# Bahrain                                            15           15         15
# Barbados                                           15           15         15
# Bolivia (Plurinational State of)                   15           15         15
# ...                                               ...          ...        ...
# United Republic of Tanzania                        15           15         15
# United States of America                           15           15         15
# Venezuela (Bolivarian Republic of)                 15           15         15
# Viet Nam                                           15           15         15
# Yemen                                              15           15         15
#
#                                     GDP  Population   thinness  1-19 years  \
# Country
# Antigua and Barbuda                  15           0                     15
# Bahamas                               0           0                     15
# Bahrain                              15           0                     15
# Barbados                             15           0                     15
# Bolivia (Plurinational State of)      0           0                     15
# ...                                 ...         ...                    ...
# United Republic of Tanzania           0           0                     15
# United States of America              0           0                     15
# Venezuela (Bolivarian Republic of)    0           0                     15
# Viet Nam                              0           0                     15
# Yemen                                 0           0                     15
#
#                                      thinness 5-9 years  \
# Country
# Antigua and Barbuda                                  15
# Bahamas                                              15
# Bahrain                                              15
# Barbados                                             15
# Bolivia (Plurinational State of)                     15
# ...                                                 ...
# United Republic of Tanzania                          15
# United States of America                             15
# Venezuela (Bolivarian Republic of)                   15
# Viet Nam                                             15
# Yemen                                                15
#
#                                     Income composition of resources  Schooling
# Country
# Antigua and Barbuda                                              15         15
# Bahamas                                                          15         15
# Bahrain                                                          15         15
# Barbados                                                         15         15
# Bolivia (Plurinational State of)                                 15         15
# ...                                                             ...        ...
# United Republic of Tanzania                                       0          0
# United States of America                                          0          0
# Venezuela (Bolivarian Republic of)                               15         15
# Viet Nam                                                         15         15
# Yemen                                                            15         15
#
# [62 rows x 21 columns]

# %%
data2.loc[data2.isna().any(axis = 1)].groupby(by = 'Status').count()
# Out:
#             Country  Year  Life expectancy   Adult Mortality  infant deaths  \
# Status
# Developed       195   195               195              195            195
# Developing      575   575               565              565            575
#
#             Alcohol  percentage expenditure  Hepatitis B  Measles    BMI   \
# Status
# Developed       195                     195           75       195    195
# Developing      559                     575          560       575    543
#
#             ...  Polio  Total expenditure  Diphtheria    HIV/AIDS  GDP  \
# Status      ...
# Developed   ...    195                195          195        195  135
# Developing  ...    575                545          575        575  242
#
#             Population   thinness  1-19 years   thinness 5-9 years  \
# Status
# Developed          105                    195                  195
# Developing          54                    543                  543
#
#             Income composition of resources  Schooling
# Status
# Developed                               150        150
# Developing                              463        467
#
# [2 rows x 21 columns]

# %% [markdown]
# It appears that many countries (including those that are relatively 'Developed') just don't measure many key variables. Since many of these columns (Eg. Mortality, Alcohol, BMI, etc.) are likely to play a big role in determining life expectancy, we must approximate these values by comparing similar countries.
#
# To determine the rank of comparision, we create an initial correlation matrix to understand what is currently affecting life expectancy.

# %%
corr = data2.corr()

plt.figure(figsize=(15, 15))
ax = sns.heatmap(corr, annot=True, fmt = '.2f', cmap='RdGy')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (20.0, 0.0)

# %%
data4 = data2[['Life expectancy ','Country', 'Status' ]].copy()

cat_vars = ['Country', 'Status']

for col in cat_vars:
    data4 = pd.concat([data4, pd.get_dummies(data4[col], drop_first = True)], axis = 1)
    
    
corr = data4.corr()

ax = sns.heatmap(corr, annot=True, fmt = '.2f', cmap='RdGy')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-c6e9eaae4a5e> in <module>
#       8
#       9 corr = data4.corr()
# ---> 10 ax = sns.heatmap(corr, annot=True, fmt = '.2f', cmap='RdGy')
#      11 bottom, top = ax.get_ylim()
#      12 ax.set_ylim(bottom + 0.5, top - 0.5)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     526     if square:
#     527         ax.set_aspect("equal")
# --> 528     plotter.plot(ax, cbar_ax, kwargs)
#     529     return ax
#     530
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in plot(self, ax, cax, kws)
#     327         # Annotate the cells with the formatted values
#     328         if self.annot:
# --> 329             self._annotate_heatmap(ax, mesh)
#     330
#     331
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/matrix.py in _annotate_heatmap(self, ax, mesh)
#     239                                        self.annot_data.flat):
#     240             if m is not np.ma.masked:
# --> 241                 lum = relative_luminance(color)
#     242                 text_color = ".15" if lum > .408 else "w"
#     243                 annotation = ("{:" + self.fmt + "}").format(val)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/seaborn/utils.py in relative_luminance(color)
#     568     """
#     569     rgb = mpl.colors.colorConverter.to_rgba_array(color)[:, :3]
# --> 570     rgb = np.where(rgb <= .03928, rgb / 12.92, ((rgb + .055) / 1.055) ** 2.4)
#     571     lum = rgb.dot([.2126, .7152, .0722])
#     572     try:
#
# KeyboardInterrupt:
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x1140fa050> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1905         if not self._is_idle_drawing:
#    1906             with self._idle_draw_cntx():
# -> 1907                 self.draw(*args, **kwargs)
#    1908
#    1909     def draw_cursor(self, event):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     716                     textrenderer.draw_text(gc, x, y, clean_line,
#     717                                            textobj._fontproperties, angle,
# --> 718                                            ismath=ismath, mtext=mtext)
#     719
#     720         gc.restore()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#     189
#     190         self._renderer.draw_text_image(
# --> 191             font, np.round(x - xd + xo), np.round(y + yd + yo) + 1, angle, gc)
#     192
#     193     def get_text_width_height_descent(self, s, prop, ismath):
#
# KeyboardInterrupt:
